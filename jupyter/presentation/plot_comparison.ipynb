# %% [markdown]
# This jupyter visualises plots created

# %%
# Define some variables
base_figure_dir = "../../new_figures"

# Import library for visualization
import sys
sys.path.append("../../python")
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib.image as mpimg
from os import listdir, path, makedirs
from auditing_setup.election_setting import Election

# %% [markdown]
# # Define some functions

# %%
# We parse the file structure into a dictionary/pandas dataframe
def parse_election_name_to_object(election_string):
    election_params = {}
    for election_pair in election_string.split("_"):
        key, value = election_pair.split("=")
        election_params[key] = eval(value.lstrip("0"))
    return Election(**election_params)
            

def parse_figure_dir(figure_dir):
    figure_dir_df = pd.DataFrame()
    for election_dir_file in listdir(figure_dir):
        try:
            if path.isdir(path.join(figure_dir, election_dir_file)):
                figure_types = {}
                for figure_file in listdir(path.join(figure_dir, election_dir_file)):
                    if figure_types[figure_file.rsplit(".", 1)[-1]] != "png":
                        continue
                    figure_types[figure_file.rsplit(".", 1)[0]] = \
                        path.join(figure_dir, election_dir_file, figure_file)
                election_dir_params = {"election": parse_election_name_to_object(election_dir_file), 
                                       "path": path.join(figure_dir, election_dir_file),
                                       "figure_types": figure_types}
                figure_dir_df = figure_dir_df.append(election_dir_params, ignore_index=True)
        except ValueError as ve:
            pass
    return figure_dir_df


def compare_figures(figure_dir_df, elections, figure_type, figsize=(20, 20)):
    figure_dir_list = []
    for election in elections:
        figure_dir_list.append(figure_dir_df[figure_dir_df.election == election].iloc[0])
    figure_dir_df = pd.DataFrame(figure_dir_list)
    ncols = int(np.sqrt(len(figure_dir_df))) + 1
    nrows = int(len(figure_dir_df) / ncols) + 1
    fig, axes = plt.subplots(nrows, ncols, figsize=figsize)
    try:
        axes = axes.flat[:]
    except Exception as e:
        axes = np.array([axes])
    for ax, (index, row) in zip(axes, figure_dir_df.iterrows()):
        img=mpimg.imread(row["figure_types"][figure_type])
        ax.imshow(img)
    [ax.set_axis_off() for ax in axes.flat[len(elections): nrows*ncols]]
    fig.tight_layout()
    return fig

def make_plot_name(n=None, m=None, p=None, replacement=None, step=None):
    name = ""
    if n:
        name += "_" if name else ""
        name += "n={:06d}".format(n)
    if m:
        name += "_" if name else ""
        name += "m={:05d}".format(m)
    if p:
        name += "_" if name else ""
        name += "p={:.3f}".format(p)
    if replacement is not None:
        name += "_" if name else ""
        name += "replacement={}".format(bool(replacement))
    if step:
        name += "_" if name else ""
        name += "step={}".format(step)
    return name
            
figure_dir_df = parse_figure_dir(base_figure_dir)
figure_dir_df
# Out:
#                                              election  \
# 0   n=000500_m=00500_p=0.500_replacement=False_step=1
# 1   n=010000_m=01000_p=0.500_replacement=False_step=1
# 2   n=005000_m=00500_p=0.500_replacement=False_step=5
# 3   n=005000_m=00500_p=0.500_replacement=False_ste...
# 4    n=010000_m=01000_p=0.500_replacement=True_step=1
# 5   n=001000_m=01000_p=0.500_replacement=False_step=1
# 6   n=020000_m=02000_p=0.500_replacement=False_ste...
# 7   n=000500_m=00500_p=0.500_replacement=False_ste...
# 8   n=005000_m=00500_p=0.500_replacement=False_step=1
# 9   n=020000_m=02000_p=0.500_replacement=False_ste...
# 10  n=005000_m=00500_p=0.500_replacement=False_ste...
# 11  n=000500_m=00500_p=0.500_replacement=False_step=5
# 12   n=020000_m=02000_p=0.500_replacement=True_step=1
# 13  n=005000_m=00500_p=0.500_replacement=False_ste...
# 14  n=000500_m=00500_p=0.500_replacement=False_ste...
# 15  n=020000_m=02000_p=0.500_replacement=False_step=1
# 16  n=000500_m=00500_p=0.500_replacement=False_ste...
# 17  n=000500_m=00500_p=0.500_replacement=False_ste...
# 18  n=000500_m=00500_p=0.500_replacement=False_ste...
# 19  n=020000_m=02000_p=0.500_replacement=False_ste...
# 20   n=005000_m=00500_p=0.500_replacement=True_step=1
# 21  n=020000_m=02000_p=0.500_replacement=False_ste...
# 22   n=001000_m=01000_p=0.500_replacement=True_step=1
# 23  n=005000_m=00500_p=0.500_replacement=False_ste...
# 24  n=005000_m=00500_p=0.500_replacement=False_ste...
# 25  n=005000_m=00500_p=0.500_replacement=False_ste...
# 26   n=000500_m=00500_p=0.500_replacement=True_step=1
#
#                                          figure_types  \
# 0   {'unconditional_mean': '../../new_figures/n=00...
# 1   {'unconditional_mean': '../../new_figures/n=01...
# 2   {'unconditional_mean': '../../new_figures/n=00...
# 3   {'unconditional_mean': '../../new_figures/n=00...
# 4   {'unconditional_mean': '../../new_figures/n=01...
# 5   {'unconditional_mean': '../../new_figures/n=00...
# 6   {'unconditional_mean': '../../new_figures/n=02...
# 7   {'unconditional_mean': '../../new_figures/n=00...
# 8   {'unconditional_mean': '../../new_figures/n=00...
# 9   {'unconditional_mean': '../../new_figures/n=02...
# 10  {'unconditional_mean': '../../new_figures/n=00...
# 11  {'unconditional_mean': '../../new_figures/n=00...
# 12  {'unconditional_mean': '../../new_figures/n=02...
# 13  {'unconditional_mean': '../../new_figures/n=00...
# 14  {'unconditional_mean': '../../new_figures/n=00...
# 15  {'unconditional_mean': '../../new_figures/n=02...
# 16  {'unconditional_mean': '../../new_figures/n=00...
# 17  {'unconditional_mean': '../../new_figures/n=00...
# 18  {'unconditional_mean': '../../new_figures/n=00...
# 19  {'unconditional_mean': '../../new_figures/n=02...
# 20  {'unconditional_mean': '../../new_figures/n=00...
# 21  {'unconditional_mean': '../../new_figures/n=02...
# 22  {'unconditional_mean': '../../new_figures/n=00...
# 23  {'unconditional_mean': '../../new_figures/n=00...
# 24  {'unconditional_mean': '../../new_figures/n=00...
# 25  {'unconditional_mean': '../../new_figures/n=00...
# 26  {'unconditional_mean': '../../new_figures/n=00...
#
#                                                  path
# 0   ../../new_figures/n=000500_m=00500_p=0.500_rep...
# 1   ../../new_figures/n=010000_m=01000_p=0.500_rep...
# 2   ../../new_figures/n=005000_m=00500_p=0.500_rep...
# 3   ../../new_figures/n=005000_m=00500_p=0.500_rep...
# 4   ../../new_figures/n=010000_m=01000_p=0.500_rep...
# 5   ../../new_figures/n=001000_m=01000_p=0.500_rep...
# 6   ../../new_figures/n=020000_m=02000_p=0.500_rep...
# 7   ../../new_figures/n=000500_m=00500_p=0.500_rep...
# 8   ../../new_figures/n=005000_m=00500_p=0.500_rep...
# 9   ../../new_figures/n=020000_m=02000_p=0.500_rep...
# 10  ../../new_figures/n=005000_m=00500_p=0.500_rep...
# 11  ../../new_figures/n=000500_m=00500_p=0.500_rep...
# 12  ../../new_figures/n=020000_m=02000_p=0.500_rep...
# 13  ../../new_figures/n=005000_m=00500_p=0.500_rep...
# 14  ../../new_figures/n=000500_m=00500_p=0.500_rep...
# 15  ../../new_figures/n=020000_m=02000_p=0.500_rep...
# 16  ../../new_figures/n=000500_m=00500_p=0.500_rep...
# 17  ../../new_figures/n=000500_m=00500_p=0.500_rep...
# 18  ../../new_figures/n=000500_m=00500_p=0.500_rep...
# 19  ../../new_figures/n=020000_m=02000_p=0.500_rep...
# 20  ../../new_figures/n=005000_m=00500_p=0.500_rep...
# 21  ../../new_figures/n=020000_m=02000_p=0.500_rep...
# 22  ../../new_figures/n=001000_m=01000_p=0.500_rep...
# 23  ../../new_figures/n=005000_m=00500_p=0.500_rep...
# 24  ../../new_figures/n=005000_m=00500_p=0.500_rep...
# 25  ../../new_figures/n=005000_m=00500_p=0.500_rep...
# 26  ../../new_figures/n=000500_m=00500_p=0.500_rep...

# %%
figure_dir = path.join(base_figure_dir, "comparisons")
if not path.exists(figure_dir):
    makedirs(figure_dir)
    
figure_types = [
    "conditional_quantile0_25",
    "conditional_quantile0_50",
    "conditional_quantile0_75",
    "conditional_quantile0_90",
    "conditional_quantile0_99",
    "unconditional_quantile0_25",
    "unconditional_quantile0_50",
    "unconditional_quantile0_75",
    "unconditional_quantile0_90",
    "unconditional_quantile0_99",
    "unconditional_mean",
    "unconditional_mean_with_recount",
    "power",
    "conditionalmean"
]

# %%
# investigate how the sampling size affect elections
default_args = dict(n = 500, m = 500, replacement = False, p = 0.5)
steps = [1, 5, 10, 20, 50, 100, 250]
elections = [Election(**default_args, step=step) for step in steps]
figsize = [90,] * 2

for figure_type in figure_types:
    fig1 = compare_figures(figure_dir_df, elections, figure_type, figsize=figsize)
    fig1.savefig(path.join(figure_dir, "{}-{}.png"
                           .format(make_plot_name(**default_args), figure_type)))
    plt.close()

# %%
# investigate how the sampling size affect elections
default_args = dict(n = 20000, m = 2000, replacement = False, p = 0.5)
steps = [1, 100, 500, 1000, 2000]
elections = [Election(**default_args, step=step) for step in steps]

for figure_type in figure_types:
    fig1 = compare_figures(figure_dir_df, elections, figure_type, figsize=figsize)
    fig1.savefig(path.join(figure_dir, "{}-{}.png"
                           .format(make_plot_name(**default_args), figure_type)))
    plt.close()

# %%
# Effect of size of step to election
default_args = dict(n = 5000, m = 500, replacement = False, p = 0.5)
steps = [1, 5, 10, 20, 50, 100, 250, 500]
elections = [Election(**default_args, step=step) for step in steps]

for figure_type in figure_types:
    fig1 = compare_figures(figure_dir_df, elections, figure_type, figsize=figsize)
    fig1.savefig(path.join(figure_dir, "{}-{}.png"
                           .format(make_plot_name(**default_args), figure_type)))
    plt.close()

# %%
# Effect of sample size
default_args = dict(replacement = False, p = 0.5, step=1)
ns = [5000, 10000, 20000]
elections = [Election(**default_args, n=n, m=n//10) for n in ns]

for figure_type in figure_types:
    fig1 = compare_figures(figure_dir_df, elections, figure_type, figsize=figsize)
    fig1.savefig(path.join(figure_dir, "{}-{}.png"
                           .format(make_plot_name(**default_args), figure_type)))
    plt.close()

# %%
# Effect of replacement 
default_args = dict(p = 0.5, step=1)
ns = [500, 1000, 5000, 10000, 20000]
ms = [500, 1000, 500, 1000, 2000]
replacements = [True, False]
nms = list(zip(ns, ms))
elections = [Election(**default_args, n=n, m=m, replacement=replacement) for n, m in nms for replacement in replacements]
figsize = [100,] * 2

for figure_type in figure_types:
    fig1 = compare_figures(figure_dir_df, elections, figure_type, figsize=figsize)
    fig1.savefig(path.join(figure_dir, "{}-{}.png"
                           .format(make_plot_name(**default_args), figure_type)))
    plt.close()
